# %%
import pandas as pd
d=pd.read_csv("sales.csv")
d
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
d.dtypes
# Out:
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
d.head(10)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
# 5              Australia and Oceania        Solomon Islands        Baby Food
# 6                 Sub-Saharan Africa                 Angola        Household
# 7                 Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                 Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                 Sub-Saharan Africa                Senegal           Cereal
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# ...

# %%
d.tail(10).head(2)
# Out:
#                    Region       Country        Item Type Sales Channel  \
# 90     Sub-Saharan Africa  Sierra Leone  Office Supplies       Offline
# 91  Australia and Oceania     Australia        Beverages       Offline
#
#    Order Priority Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 90              H  12/6/2016  621386563  12/14/2016         948      651.21
# 91              H   7/7/2014  240470397   7/11/2014        9389       47.45
#
#     Unit Cost  Total Revenue  Total Cost  Total Profit
# 90     524.96      617347.08   497662.08     119685.00
# 91      31.79      445508.05   298476.31     147031.74

# %%
order=d["Order ID"]
order
order.head()
# Out:
# 0    669165933
# 1    963881480
# 2    341417157
# 3    514321792
# 4    115456712
# Name: Order ID, dtype: int64

# %%
order.dtypes
type(order)
# Out:
# pandas.core.series.Series

# %%
d[["Order ID","Country"]]
# Out:
#      Order ID                Country
# 0   669165933                 Tuvalu
# 1   963881480                Grenada
# 2   341417157                 Russia
# 3   514321792  Sao Tome and Principe
# 4   115456712                 Rwanda
# ..        ...                    ...
# 95  512878119                   Mali
# 96  810711038               Malaysia
# 97  728815257           Sierra Leone
# 98  559427106                 Mexico
# 99  665095412             Mozambique
#
# [100 rows x 2 columns]

# %%
d[d["Order ID"].notna()]["Order ID"].head()
# Out:
# 0    669165933
# 1    963881480
# 2    341417157
# 3    514321792
# 4    115456712
# Name: Order ID, dtype: int64

# %%
d.shape
# Out:
# (100, 14)

# %%
d.loc[2,["Country","Region"]]
# Out:
# Country    Russia
# Region     Europe
# Name: 2, dtype: object

# %%
d.iloc[0:3,3:5]
# Out:
#   Sales Channel Order Priority
# 0       Offline              H
# 1        Online              C
# 2       Offline              L

# %%
k=d[["Order ID"]]
k
# Out:
#      Order ID
# 0   669165933
# 1   963881480
# 2   341417157
# 3   514321792
# 4   115456712
# ..        ...
# 95  512878119
# 96  810711038
# 97  728815257
# 98  559427106
# 99  665095412
#
# [100 rows x 1 columns]

# %%
pass=str(input("Enter your password"))
def
