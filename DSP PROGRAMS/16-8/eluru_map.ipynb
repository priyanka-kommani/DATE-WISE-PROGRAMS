# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium as f
eluru=f.Map(location=[16.7107,81.0952])
eluru
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#resize our map by using the branca library in Python
from branca.element import Figure
fig=Figure(width=550,height=350)
map1=f.Map(location=[16.7107,81.0952],zoom_start=12,min_zoom=8,max_zoom=14)
fig.add_child(map1)
map1
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Creating Basemap
fig1=Figure(width=550,height=350)
map2=f.Map(location=[16.7107,81.0952],tiles='cartodbpositron',zoom_start=8)
fig1.add_child(map2)

#Adding markers to the map
f.Marker(location=[16.789426546526816, 80.90999756904735],popup='Default popup Marker1',tooltip='Click here to see more details',icon=f.Icon(color='red',icon='church')).add_to(map2)
f.Marker(location=[16.78024360727237, 80.87119137107945],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see Popup</strong>',icon=f.Icon(color='green',prefix='glyphicon',icon='temple')).add_to(map2)
f.Marker(location=[16.783694965369197, 80.86097751969277],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Guntur</strong>',icon=f.Icon(color='purple',prefix='fa',icon='music')).add_to(map2)

map2
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
coor1=[[16.786180726107332, 80.8549801006538],
[16.78256506337164, 80.86287652357457],
[16.78092155756096, 80.87008630102396],
[16.781250259860446, 80.88210259677295],
[16.78420855496468, 80.88587914686549],
[16.787495495492983, 80.89102898790075],
[16.789467632505694, 80.89789544261447],
[16.789467632505694, 80.90029870176426],
[16.7911110643713, 80.9013286699713],
[16.7911110643713, 80.9040752518568],
[16.786509419307002, 80.92124138864106],
[16.789138944425805, 80.93051110250457],
[16.789138944425805, 80.94321404372494],
[16.78157896159126, 80.9600368577735],
[16.774676105837376, 80.96827660342996],
[16.768101724426757, 80.98063622191462],
[16.761198379305885, 80.98921929030676],
[16.75626726512227, 81.01496849548316],
[16.755938519632988, 81.01805840010432],
[16.748048457540378, 81.03385124594585],
[16.74541836417412, 81.04071770065956],
[16.739500521290964, 81.05925712838656],
[16.738514196268625, 81.06269035574341],
[16.73226735255437, 81.06715355130731],
[16.729308249850064, 81.07607994243514],
[16.724047509402677, 81.0843196880916],
[16.714512047432827, 81.09015617459823]]
coor2=[[16.78743246993115, 80.85394925187751],[16.780201123294997, 80.86974209752545],[16.77691405656353, 80.87660855215502],
       [16.771654631541804, 80.88244503859015],[16.76902486446411, 80.88484829771048],[16.760149132084674, 80.8906847841456],[16.74930045239778, 80.89514797965481],
       [16.727601238671554, 80.91300076169165],[16.72135403730106, 80.9181506026638],[16.719710002925297, 80.92021053905269],[16.70688604855612, 80.9291369300711],
       [16.700309327464446, 80.93909328928395],[16.69241696318584, 80.94252651659872],[16.683208792818704, 80.94630306664497],[16.674657951760086, 80.95076626215418],
       [16.663146600570915, 80.95866268497817],[16.641437597956738, 80.96758907599659],[16.63749024231455, 80.97685878974647],[16.643740184544804, 80.98681514895934],
       [16.661830973489995, 81.0043246082647],[16.67498683733186, 81.0194308084497],[16.683208792818704, 81.02732723127369],[16.685182009528585, 81.03213374951437],
       [16.69241696318584, 81.04346339965313],[16.699322799763433, 81.0530764361345],[16.703926552098867, 81.06783931358805],[16.70688604855612, 81.0729891545602],
       [16.70885902070499, 81.08775203201374],[16.714120180059226, 81.08878200020818],[16.716750705339937, 81.0901552911341],[16.71050314858377, 81.09496180937478]
]

# %%
fig5=Figure(height=550,width=750)
map5=f.Map(location=[16.7107,81.0952],tiles='cartodbpositron',zoom_start=10)
fig5.add_child(map5)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
f1=f.FeatureGroup("route_1")
f2=f.FeatureGroup("route_2")
#f3=folium.FeatureGroup("Vehicle
line_1=f.vector_layers.PolyLine(coor1,popup='<b>route 11</b>',tooltip='route_1',color='green',weight=4).add_to(f1)
line_2=f.vector_layers.PolyLine(coor2,popup='<b>route 2</b>',tooltip='route2',color='red',weight=4).add_to(f2)
#line_3=folium.vector_layers.PolyLine(coords_3,popup='<b>Path of Vehicle_3</b>',tooltip='Vehicle_3',color='green',weight=10).add_to(f3)

f1.add_to(map5)
f2.add_to(map5)
#f3.add_to(map5)
f.LayerControl().add_to(map5)
map5
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
f.Marker(location=[16.779262135516472, 80.87489231759733],popup='Marker1',tooltip='LFC CHURCH',icon=f.Icon(color='red',icon='plus')).add_to(map5)
f.Marker(location=[16.780095968469723, 80.87081611836409],popup='Marker2',tooltip='TEMPLE',icon=f.Icon(color='green',prefix='glyphicon',icon='flag')).add_to(map5)
f.Marker(location=[16.783694965369197, 80.86097751969277],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>MUSIC</strong>',icon=f.Icon(color='purple',prefix='glyphicon',icon='music')).add_to(map5)
f.Marker(location=[16.75511282206718, 81.01415335875602],popup='Marker4',tooltip='reliance gas',icon=f.Icon(color='vio;let',icon='record')).add_to(map5)
f.Marker(location=[16.749565132224998, 81.03303610898728],popup='Marker5',tooltip='hospital',icon=f.Icon(color='green',prefix='glyphicon',icon='plus')).add_to(map5)
map5
# Out:
# C:\Users\PRIYANKA\AppData\Local\Temp\ipykernel_5428\3618136649.py:4: UserWarning: color argument of Icon should be one of: {'darkgreen', 'white', 'lightblue', 'beige', 'darkred', 'lightgreen', 'red', 'green', 'gray', 'black', 'pink', 'purple', 'darkpurple', 'cadetblue', 'blue', 'lightred', 'darkblue', 'lightgray', 'orange'}.
#   f.Marker(location=[16.75511282206718, 81.01415335875602],popup='Marker4',tooltip='reliance gas',icon=f.Icon(color='vio;let',icon='record')).add_to(map5)
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...

# %%
f.Marker(location=[16.73908956129302, 80.90158608309218],popup='Marker1',tooltip='prandana pvt',icon=f.Icon(color='red',icon='tint')).add_to(map5)
f.Marker(location=[16.755795864487386, 80.89389571257803],popup='Marker2',tooltip='TEMPLE',icon=f.Icon(color='green',prefix='glyphicon',icon='flag')).add_to(map5)
f.Marker(location=[16.702954802444143, 80.93536720962975],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>filling station</strong>',icon=f.Icon(color='purple',prefix='glyphicon',icon='tint')).add_to(map5)
f.Marker(location=[16.71697603641134, 81.03509120820337],popup='Marker4',tooltip="filling station",icon=f.Icon(color='violet',prefix='glyphicon',icon='tint')).add_to(map5)
f.Marker(location=[16.734706063035336, 81.06733448293879],popup='Marker5',tooltip='raj dhaba',icon=f.Icon(color='green',prefix='glyphicon',icon='cutlery')).add_to(map5)
f.Marker(location=[16.68824936001429, 81.02534268910135],popup='Marker5',tooltip='cr reddy clg',icon=f.Icon(color='green',prefix='glyphicon',icon='user')).add_to(map5)

map5
# Out:
# C:\Users\PRIYANKA\AppData\Local\Temp\ipykernel_5428\1916211683.py:4: UserWarning: color argument of Icon should be one of: {'darkgreen', 'white', 'lightblue', 'beige', 'darkred', 'lightgreen', 'red', 'green', 'gray', 'black', 'pink', 'purple', 'darkpurple', 'cadetblue', 'blue', 'lightred', 'darkblue', 'lightgray', 'orange'}.
#   f.Marker(location=[16.71697603641134, 81.03509120820337],popup='Marker4',tooltip="filling station",icon=f.Icon(color='violet',prefix='glyphicon',icon='tint')).add_to(map5)
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...
